# %% [markdown]
# ### COCKTAILS

# %%
import pandas as pd
import src.exploring as exploring
import src.transforming as transforming
import src.cleaning as cleaning
import src.visualization as visual
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_base = pd.read_csv("../project-II-pipelines/data/iba-cocktails-web.csv")
df_base_scrap = transforming.scrap_df_base(df_base)
df_base_scrap.to_csv("../project-II-pipelines/data/first_diffs_scrap.csv") #Checkpoint
df_base_scrap = pd.read_csv("../project-II-pipelines/data/first_diffs_scrap.csv") # Avoiding extra calls
df_base_diffs = df_base_scrap[df_base_scrap['diffords_url'] != 'Unknown']
df_base_trans = transforming.exe_translation(df_base_diffs)
df_base_trans.to_csv("../project-II-pipelines/data/second_diffs_translated.csv")
df_base_trans = pd.read_csv("../project-II-pipelines/data/second_diffs_translated.csv") # Avoiding extra calls
df_final = transforming.scrap_details(df_base_trans)
# Out:
# /Users/pere/Documents/Ironhack/Projects/project-II-pipelines/src/transforming.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["method_esp"] = l_ins_esp
# /Users/pere/Documents/Ironhack/Projects/project-II-pipelines/src/transforming.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['Flute glass', 'Old-fashioned glass', 'Collins glass', 'Highball (max 10oz/300ml)', 'Flute glass', 'Coupe glass', 'Collins glass', 'Flute glass', 'Old-fashioned glass', 'Coupe glass', 'Old-fashioned glass', 'Martini (large 10oz) glass', 'Highball (max 10oz/300ml)', 'Toddy glass', 'Old-fashioned glass', 'Goblet glass', 'Julep tin', 'Collins glass', 'Copper mug or Collins glass', 'Poco grande', 'Goblet glass', 'Sling glass', 'Collins glass', 'Martini glass', 'Zombie or Collins glass', 'Coupe glass', 'Coupe glass', 'Double old-fashioned', 'Martini glass', 'Double old-fashioned', 'Martini glass', 'Coupe glass', 'Old-fashioned glass', 'Highball (max 10oz/300ml)', 'Collins glass', 'Coupe glass', 'Old-fashioned glass', 'Sling glass', 'Coupe glass', 'Martini glass', 'Old-fashioned glass', 'Tiki mug or collins', 'Nick & Nora glass', 'Old-fashioned glass', 'Coupe glass', 'Collins glass', 'Coupe glass', 'Collins glass', 'Coupe glass', 'Coupe glass', 'Old-fashioned glass', 'Flute glass', 'Nick & Nora glass', 'Coupe glass', 'Nick & Nora glass', 'Martini glass', 'Highball (max 10oz/300ml)', 'Nick & Nora glass', 'Collins glass', 'Coupe glass', 'Coupe glass', 'Coupe glass', 'Coupe glass', 'Old-fashioned glass', 'Old-fashioned glass', 'Coupe glass', 'Collins glass', 'Old-fashioned glass', 'Old-fashioned glass', 'Coupe glass', 'Old-fashioned glass', 'Coupe glass', 'Old-fashioned glass', 'Coupe glass']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["diffords_url"] != 'Unknown', "diff_glass"] = l_serve
# /Users/pere/Documents/Ironhack/Projects/project-II-pipelines/src/transforming.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['Peach slice on rim', 'Lemon slice & Luxardo Maraschino cherry on stick (sail)', 'Celery salt & black pepper rim + garnish with celery stick, cherry tomato & strip yellow bell pepper', 'Stirrer (spoon, wooden lolly stick or stick cut from sugar cane)', 'Orange zest twist (discarded)', 'Orange zest twist (flamed)', 'Lime wedge', 'Lemon zest twist on rim', 'Lemon zest twist', 'Sponge biscuit', 'Dust with grated chocolate and add a mint sprigs bouquet. Serve with a straw.', 'Luxardo maraschino cherry &/or lime wedge/wheel', 'Lemon peel (whole)', 'Dust with freshly grated nutmeg and/or float 3 coffee beans', 'Salt rim (optional) & lime wedge', 'Orange zest twist (discarded) & orange slice', 'Mint sprigs bouquet dusted with icing sugar', 'Mint sprigs bouquet', 'Lime slice, mint sprigs bouquet & straw', 'Parasol, pineapple wedge & Luxardo Maraschino cherry', 'Float three drops of Amargo Chuncho or Angostura aromatic bitters to signify health wealth and happiness.', 'Pineapple slice and Luxardo maraschino cherry', 'Lime wheel', 'Lemon zest twist', 'Mint sprigs bouquet & straw', 'Pineapple wedge', 'Orange zest twist', 'Blackberry & lemon slice dusted with icing sugar', "Lemon zest twist (discarded) plus float coffee beans arranged in a petal formation floating in the centre of the drinks creamy surface. The floating of three beans comes from the traditional serving of Sambuca in Italy where the floating beans are called con la mosca, meaning 'with the fly'. Three beans represent health, wealth and happiness.", 'Lime wedge', 'Pineapple wedge on rim', 'Lime zest twist (discarded) & garnish with dehydrated lime slice wheel', 'Lemon zest twist', 'Mint sprig bouquet', 'Salt rim (optional) & pink or red grapefruit wedge', 'Lemon zest twist', 'Skewered candied ginger', 'Lemon slice & seasonal berries', 'Mint leaf', 'Fresh chilli on rim (warn drinker not to eat)', 'Orange zest twist &/or skewered olive', 'Pineapple cubes, Luxardo Maraschino cherry, lime wedge & mint sprig bouquet', 'Orange zest twist (discarded) & Luxardo Maraschino cherry', 'Lime wedge', 'None', 'Banana carved to resemble a bird OR pineapple wedge, Luxardo maraschino cherry & half orange wheel.', 'Dust with freshly grated nutmeg', 'Orange slice', 'Orange zest twist, or apple wedge on rim, or float (dehydrated) apple slice', 'Lemon zest twist (& optional sugar rim)', 'Orange zest twist', 'Some merely shove a wide long piece of lemon peel around the inside of the glass rim, leaving the drinker to push the peel down into the glass in order to sip from the drink. Instead I prefer the peel to become a watertight extension to the glass.\r\n\r\nFind a lemon which fits snugly in the top of a small wine, flute or sour glass. Cut off both ends of the fruit and carefully remove the pulp to leave a barrel-shaped shell of skin. Place in the top of the glass. Wet the edge of the glass and exposed fruit shell with sugar syrup and dip in caster sugar to frost the edge of both peel and glass. Leave for a couple of hours to form a hard crust that helps secure the peel.', 'Luxardo Maraschino cherry', 'Lemon zest twist (expressed and discarded) & skewered raspberry', 'Lime zest twist (expressed & then discarded) & lime wedge on rim', "Chilled skewered olive or lemon zest twist (or served Dicken's-style without a garnish)", 'Lemon slice on rim & mint sprig', 'Orange zest twist  (go easy - orange oils add unwanted bitterness if overdone)', 'Orange slice & Luxardo Maraschino cherry on stick (sail)', 'Orange zest twist (discarded) & Luxardo Maraschino Cherry', 'Orange zest twist', 'Luxardo Maraschino cherry', 'Orange zest twist', 'Orange wedge or slice and/or orange zest twist', 'Orange zest twist', 'Orange zest twist (discarded & replaced with apricot wedge when in season)', 'Orange slice & mint  ...
#   df.loc[df["diffords_url"] != 'Unknown', "diff_garnish"] = l_garnish
# /Users/pere/Documents/Ironhack/Projects/project-II-pipelines/src/transforming.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['105', '197', '', '', '', '160', '', '', '185', '', '', '345', '', '163', '', '67', '', '', '207', '', '', '227', '210', '191', '', '', '172', '176', '', '141', '208', '', '223', '', '158', '168', '220', '', '', '', '', '193', '136', '180', '145', '', '231', '', '', '', '152', '174', '150', '', '', '150', '', '', '', '187', '169', '180', '180', '119', '213', '153', '', '148', '', '', '195', '201', '', '']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["diffords_url"] != 'Unknown', "diff_nutrition"] = l_nutrition

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    74 non-null     int64
#  1   Unnamed: 0      74 non-null     int64
#  2   category        74 non-null     object
#  3   name            74 non-null     object
#  4   ingredients     74 non-null     object
#  5   method          74 non-null     object
#  6   garnish         53 non-null     object
#  7   diffords        74 non-null     object
#  8   diffords_url    74 non-null     object
#  9   method_esp      74 non-null     object
#  10  diff_glass      74 non-null     object
#  11  diff_garnish    74 non-null     object
#  12  diff_nutrition  74 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 7.6+ KB

# %%
df_final.to_csv("../project-II-pipelines/data/cocktails_final.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/pere/Documents/Ironhack/Projects/project-II-pipelines/main.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/pere/Documents/Ironhack/Projects/project-II-pipelines/main.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df_final.drop("Unnamed: 0.2",axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/Users/pere/Documents/Ironhack/Projects/project-II-pipelines/main.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> df_final.drop("Unnamed: 0",axis=1,inplace=True)
#       <a href='vscode-notebook-cell:/Users/pere/Documents/Ironhack/Projects/project-II-pipelines/main.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> df_final.to_csv("../project-II-pipelines/data/cocktails_final.csv")
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df_final = pd.read_csv("../project-II-pipelines/data/cocktails_final.csv") # Avoiding extra calls
df_final
# Out:
#     Unnamed: 0               category                name  \
# 0            0  Contemporary Classics             Bellini
# 1            1  Contemporary Classics       Black Russian
# 2            2  Contemporary Classics         Bloody Mary
# 3            3  Contemporary Classics          Caipirinha
# 4            4  Contemporary Classics  Champagne Cocktail
# ..         ...                    ...                 ...
# 69          69     The Unforgettables             Sidecar
# 70          70     The Unforgettables             Stinger
# 71          71     The Unforgettables              Tuxedo
# 72          72     The Unforgettables        Whiskey Sour
# 73          73     The Unforgettables          White Lady
#
#                                           ingredients  \
# 0             100 ml Prosecco,50 ml White Peach Puree
# 1                    50 ml Vodka,20 ml Coffee Liqueur
# 2   45 ml Vodka,90 ml Tomato Juice,15 ml Fresh Lem...
# 3   60 ml Cachaça,1 Lime cut into small wedges,4 T...
# 4   90 ml Chilled Champagne,10 ml Cognac,2 dashes ...
# ..                                                ...
# 69  50 ml Cognac,20 ml Triple Sec,20 ml Fresh Lemo...
# 70           50 ml Cognac,20 ml White Crème de Menthe
# 71  30 ml Old Tom Gin,30 ml Dry Vermouth,1/2 Bar S...
# 72  45 ml Bourbon Whiskey,25 ml Fresh Lemon Juice,...
# 73  40 ml Gin,30 ml Triple Sec,20 ml Fresh Lemon J...
#
#                                                method  \
# 0   Pour peach puree into the mixing glass with ic...
# 1   Pour the ingredients into the old fashioned gl...
# 2   Stir gently all the ingredients in a mixing gl...
# 3   Place lime and sugar into a double old fashion...
# 4   Place the sugar cube with 2 dashes of bitters ...
# ..                                                ...
# 69  Pour all ingredients into a cocktail shaker, s...
# 70  Pour all ingredients into mixing glass with ic...
# 71  Pour all ingredients into mixing glass with ic...
# 72  Pour all ingredients into a cocktail shaker fi...
# 73  Pour all ingredients into a cocktail shaker, s...
#
#                                               garnish            diffords  \
# 0                                                 NaN             Bellini
# 1                                                 NaN       Black Russian
# 2                      Celery, Lemon Wedge (Optional)         Bloody Mary
# 3                                                 NaN          Caipirinha
# 4     Garnish with orange zest and maraschino cherry.  Champagne Cocktail
# ..                                                ...                 ...
# 69                                                NaN             Sidecar
# 70                               Optional mint leave.             Stinger
# 71                 Garnish with cherry and lemon zest              Tuxedo
# 72  Garnish with a half orange slice and maraschin...        Whiskey Sour
# 73                                                NaN          White Lady
#
#                                          diffords_url  \
# 0       /cocktails/recipe/202/bellini-diffords-recipe
# 1                 /cocktails/recipe/236/black-russian
# 2   /cocktails/recipe/2307/bloody-mary-diffords-re...
# 3                    /cocktails/recipe/354/caipirinha
# 4            /cocktails/recipe/393/champagne-cocktail
# ..                                                ...
# 69       /cocktails/recipe/1773/sidecar-diffords-spec
# 70                     /cocktails/recipe/1874/stinger
# 71  /cocktails/recipe/4605/tuxedo-no-2-flora-bars-...
# 72  /cocktails/recipe/2083/whiskey-sour-diffords-r...
# 73         /cocktails/recipe/2091/white-lady-cocktail
#
#                                            method_esp  \
# 0   Vierta el puré de melocotón en el vaso mezclad...
# 1   Vierta los ingredientes en el vaso old fashion...
# 2   Remover suavemente todos los ingredientes en u...
# 3   Poner la lima y el azúcar en un vaso old fashi...
# 4   Ponga el terrón de azúcar con 2 chorritos de a...
# ..                                                ...
# 69  Verter todos los ingredientes en una coctelera...
# 70  Vierta todos los ingredientes en un vaso mezcl...
# 71  Vierta todos los ingredientes en un vaso mezcl...
# 72  Vierta todos los ingredientes en una coctelera...
# 73  Verter todos los ingredientes en una coctelera...
#
#                    diff_glass  \
# 0                 Flute glass
# 1         Old-fashioned glass
# 2               Collins glass
# 3   Highball (max 10oz/300ml)
# 4                 Flute glass
# ..                        ...
# 69                Coupe glass
# 70        Old-fashioned glass
# 71                Coupe glass
# 72        Old-fashioned glass
# 73                Coupe glass
#
#                                          diff_garnish  diff_nutrition
# 0                                  Peach slice on rim           105.0
# 1   Lemon slice & Luxardo Maraschino cherry on sti...           197.0
# 2   Celery salt & black pepper rim + garnish with ...             NaN
# 3   Stirrer (spoon, wooden lolly stick or stick cu...             NaN
# 4                       Orange zest twist (discarded)             NaN
# ..                                                ...             ...
# 69  Orange zest twist (a lemon zest twist is more ...             NaN
# 70                                Mint sprigs bouquet           195.0
# 71      Orange zest twist & Luxardo Maraschino cherry           201.0
# 72  Skewered lemon slice wheel & Luxardo Maraschin...             NaN
# 73                                   Lemon zest twist             NaN
#
# [74 rows x 12 columns]

# %%
for i in df_final.index:
    try:
        elements = df_final["ingredients"][i].split(',')
        dict_ingr = {}
        for element in elements:
            if 'ml' in element:
                quantity, ingredient = [i.strip() for i in element.split(' ml')]
            if 'pcs' in element:
                quantity, ingredient = [i.strip() for i in element.split(' pc')]
            
            dict_ingr[ingredient] = quantity
            df_final["ingredients"][i] = dict_ingr
    except:
        print(elements)
# Out:
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr
# /var/folders/gy/rmsk3kj95dz94q2k0p3dx96h0000gn/T/ipykernel_23305/870781675.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["ingredients"][i] = dict_ingr

# %%
df_final.to_csv("../project-II-pipelines/data/cocktails_final_dicts.csv")
# Out:
#     Unnamed: 0               category                name  \
# 0            0  Contemporary Classics             Bellini
# 1            1  Contemporary Classics       Black Russian
# 2            2  Contemporary Classics         Bloody Mary
# 3            3  Contemporary Classics          Caipirinha
# 4            4  Contemporary Classics  Champagne Cocktail
# ..         ...                    ...                 ...
# 69          69     The Unforgettables             Sidecar
# 70          70     The Unforgettables             Stinger
# 71          71     The Unforgettables              Tuxedo
# 72          72     The Unforgettables        Whiskey Sour
# 73          73     The Unforgettables          White Lady
#
#                                           ingredients  \
# 0      {'Prosecco': '100', 'White Peach Puree': '50'}
# 1             {'Vodka': '50', 'Coffee Liqueur': '20'}
# 2   {'Vodka': '45', 'Tomato Juice': '90', 'Fresh L...
# 3                                   {'Cachaça': '60'}
# 4         {'Chilled Champagne': '90', 'Cognac': '10'}
# ..                                                ...
# 69  {'Cognac': '50', 'Triple Sec': '20', 'Fresh Le...
# 70    {'Cognac': '50', 'White Crème de Menthe': '20'}
# 71        {'Old Tom Gin': '30', 'Dry Vermouth': '30'}
# 72  {'Bourbon Whiskey': '45', 'Fresh Lemon Juice':...
# 73  {'Gin': '40', 'Triple Sec': '30', 'Fresh Lemon...
#
#                                                method  \
# 0   Pour peach puree into the mixing glass with ic...
# 1   Pour the ingredients into the old fashioned gl...
# 2   Stir gently all the ingredients in a mixing gl...
# 3   Place lime and sugar into a double old fashion...
# 4   Place the sugar cube with 2 dashes of bitters ...
# ..                                                ...
# 69  Pour all ingredients into a cocktail shaker, s...
# 70  Pour all ingredients into mixing glass with ic...
# 71  Pour all ingredients into mixing glass with ic...
# 72  Pour all ingredients into a cocktail shaker fi...
# 73  Pour all ingredients into a cocktail shaker, s...
#
#                                               garnish            diffords  \
# 0                                                 NaN             Bellini
# 1                                                 NaN       Black Russian
# 2                      Celery, Lemon Wedge (Optional)         Bloody Mary
# 3                                                 NaN          Caipirinha
# 4     Garnish with orange zest and maraschino cherry.  Champagne Cocktail
# ..                                                ...                 ...
# 69                                                NaN             Sidecar
# 70                               Optional mint leave.             Stinger
# 71                 Garnish with cherry and lemon zest              Tuxedo
# 72  Garnish with a half orange slice and maraschin...        Whiskey Sour
# 73                                                NaN          White Lady
#
#                                          diffords_url  \
# 0       /cocktails/recipe/202/bellini-diffords-recipe
# 1                 /cocktails/recipe/236/black-russian
# 2   /cocktails/recipe/2307/bloody-mary-diffords-re...
# 3                    /cocktails/recipe/354/caipirinha
# 4            /cocktails/recipe/393/champagne-cocktail
# ..                                                ...
# 69       /cocktails/recipe/1773/sidecar-diffords-spec
# 70                     /cocktails/recipe/1874/stinger
# 71  /cocktails/recipe/4605/tuxedo-no-2-flora-bars-...
# 72  /cocktails/recipe/2083/whiskey-sour-diffords-r...
# 73         /cocktails/recipe/2091/white-lady-cocktail
#
#                                            method_esp  \
# 0   Vierta el puré de melocotón en el vaso mezclad...
# 1   Vierta los ingredientes en el vaso old fashion...
# 2   Remover suavemente todos los ingredientes en u...
# 3   Poner la lima y el azúcar en un vaso old fashi...
# 4   Ponga el terrón de azúcar con 2 chorritos de a...
# ..                                                ...
# 69  Verter todos los ingredientes en una coctelera...
# 70  Vierta todos los ingredientes en un vaso mezcl...
# 71  Vierta todos los ingredientes en un vaso mezcl...
# 72  Vierta todos los ingredientes en una coctelera...
# 73  Verter todos los ingredientes en una coctelera...
#
#                    diff_glass  \
# 0                 Flute glass
# 1         Old-fashioned glass
# 2               Collins glass
# 3   Highball (max 10oz/300ml)
# 4                 Flute glass
# ..                        ...
# 69                Coupe glass
# 70        Old-fashioned glass
# 71                Coupe glass
# 72        Old-fashioned glass
# 73                Coupe glass
#
#                                          diff_garnish  diff_nutrition
# 0                                  Peach slice on rim           105.0
# 1   Lemon slice & Luxardo Maraschino cherry on sti...           197.0
# 2   Celery salt & black pepper rim + garnish with ...             NaN
# 3   Stirrer (spoon, wooden lolly stick or stick cu...             NaN
# 4                       Orange zest twist (discarded)             NaN
# ..                                                ...             ...
# 69  Orange zest twist (a lemon zest twist is more ...             NaN
# 70                                Mint sprigs bouquet           195.0
# 71      Orange zest twist & Luxardo Maraschino cherry           201.0
# 72  Skewered lemon slice wheel & Luxardo Maraschin...             NaN
# 73                                   Lemon zest twist             NaN
#
# [74 rows x 12 columns]

# %%
df_final= pd.read_csv("../project-II-pipelines/data/cocktails_final_dicts.csv")
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    74 non-null     int64
#  1   Unnamed: 0      74 non-null     int64
#  2   category        74 non-null     object
#  3   name            74 non-null     object
#  4   ingredients     74 non-null     object
#  5   method          74 non-null     object
#  6   garnish         53 non-null     object
#  7   diffords        74 non-null     object
#  8   diffords_url    74 non-null     object
#  9   method_esp      74 non-null     object
#  10  diff_glass      74 non-null     object
#  11  diff_garnish    73 non-null     object
#  12  diff_nutrition  38 non-null     float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 7.6+ KB

# %%
# Show the plot (optional)
visual.chart_types(df_final)
# Out:
# <module 'matplotlib.pyplot' from '/Users/pere/miniconda3/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
sns.scatterplot(x="category", y="diff_nutrition",data=df_final);
plt.xlabel("Categories")
plt.title("Distribution of categories by calories")
plt.ylabel('# Calories')
plt.show()

# %%
sns.histplot(x=df_final.diff_nutrition)
plt.xlabel("Calories")
plt.title("Distribution of calories")
plt.ylabel('# Cocktails')
plt.show()

# %%
top_cocktails = df_final.sort_values(by='diff_nutrition', ascending=False).head(5)

plt.figure(figsize=(10, 6))
plt.bar(top_cocktails['name'], top_cocktails['diff_nutrition'])
plt.xlabel('Cocktail Name')
plt.ylabel('Calories')
plt.title('Top 5 Cocktails by Calories')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.show()

# %%
top_cocktails = df_final.sort_values(by='diff_nutrition', ascending=True).head(5)

plt.figure(figsize=(10, 6))
plt.bar(top_cocktails['name'], top_cocktails['diff_nutrition'])
plt.xlabel('Cocktail Name')
plt.ylabel('Calories')
plt.title('Top 5 Cocktails with less calories')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.show()

# %%
glass_counts = df_final['diff_glass'].value_counts()

# Create a bar chart
plt.figure(figsize=(10, 6))
glass_counts.plot(kind='bar')
plt.xlabel('Glass Type')
plt.ylabel('Number of Cocktails')
plt.title('Number of Cocktails by Glass Type')
plt.xticks(fontsize=8)
plt.show()

# %%
garnish_counts = df_final['garnish'].value_counts().reset_index().head(10)
garnish_counts.columns = ['Garnish', 'Count']

plt.figure(figsize=(10, 6))
sns.barplot(data=garnish_counts, x='Count',y="Garnish", hue='Garnish', palette='viridis',legend=False)
plt.xlabel('Number of Cocktails')
plt.ylabel('Garnish')
plt.title('Top 10 Used Garnishes in Cocktails')
plt.xticks(rotation=90,fontsize=8)  # Rotate the x-axis labels for better readability
plt.show()
